# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt


# NOTE: these lines define global figure properties used for publication.
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg') # display figures in vector format
plt.rcParams.update({'font.size':14}) # set global font size

# %%
asList  = [1,2,3]
asArray = np.array([1,2,3]) # 1D array
rowVec  = np.array([ [1,2,3] ]) # row
colVec  = np.array([ [1],[2],[3] ]) # column

display(asList, asArray, rowVec, colVec)
# Out:
# [1, 2, 3]
# array([1, 2, 3])
# array([[1, 2, 3]])
# array([[1],
#        [2],
#        [3]])

# %% [markdown]
# The variable asArray is an orientationless array, meaning it is neither a row nor a column vector but simply a 1D list of numbers in NumPy.
#
# Orientation in NumPy is given by brackets: the outermost brackets group all of the numbers together into one object. Then, each additional set of brackets indicates a row: a row vector (variable rowVec) has all numbers in one row, while a column vector (variable colVec) has multiple rows, with each row containing one number.

# %%
print(f'asList:  {np.shape(asList)}')
print(f'asArray: {asArray.shape}')
print(f'rowVec:  {rowVec.shape}')
print(f'colVec:  {colVec.shape}')
# Out:
# asList:  (3,)
# asArray: (3,)
# rowVec:  (1, 3)
# colVec:  (3, 1)

# %% [markdown]
# ## Addition of vectors

# %%
v = np.array([[4,5,6]]) # row vector
w = np.array([[10,20,30]]).T # column vector
v+w
# Out:
# array([[14, 15, 16],
#        [24, 25, 26],
#        [34, 35, 36]])

# %%
# create a vector
v = np.array([1,2])
w = np.array([4,-6])

x = v + w
# plot that vector (and a dot for the tail)
# plt.arrow(x, y, dx, dy, **kwargs)
# This draws an arrow from (x, y) to (x+dx, y+dy).
plt.arrow(0,0,v[0],v[1],head_width=.5,width=.1, color=[.3,.3,.3], length_includes_head=True, label='v')
plt.arrow(0,0,w[0],w[1],head_width=.5,width=.1, color=[.5,.5,.5], length_includes_head=True, label='w')

plt.plot(0,0,'ko',markerfacecolor='k',markersize=7)

# plot result vector
plt.arrow(0,0,x[0],x[1],head_width=.5,width=.1, color=[.5,.9,.5], length_includes_head=True, label='v+w')

# plot a box around vector
plt.plot([v[0], x[0]], [v[1], x[1]],'--', color=[.8,.8,.8], zorder=-1, linewidth=2)
plt.plot([x[0], w[0]], [x[1], w[1]],'--', color=[.8,.8,.8], zorder=-1, linewidth=2)

# add axis lines
plt.plot([-8,8],[0,0],'--',color=[.4,.4,.4],zorder=-1)
plt.plot([0,0],[-8,8],'--',color=[.4,.4,.4],zorder=-1)

# make the plot look nicer
plt.axis('square')
plt.axis([-8,8,-8,8])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Vector Addition')
plt.grid(color = 'blue', linestyle = '--', linewidth = 0.5)
plt.xticks(np.arange(-8, 9, 2))
plt.legend()
plt.show()

# %% [markdown]
# >To add two vectors geometrically, place the vectors such that the tail of one vector is at the head of the other vector. The summed vector traverses from the tail of the first vector to the head of the second

# %%
vPlusW = v+w

# now plot all three vectors
plt.figure(figsize=(6,6))

a1 = plt.arrow(0,0,v[0],v[1],head_width=.3,width=.1,color='k',length_includes_head=True)
a2 = plt.arrow(v[0],v[1],w[0],w[1],head_width=.3,width=.1,color=[.5,.5,.5],length_includes_head=True)
a3 = plt.arrow(0,0,vPlusW[0],vPlusW[1],head_width=.3,width=.1,color=[.8,.8,.8],length_includes_head=True)


# make the plot look a bit nicer
plt.grid(linestyle='--',linewidth=.5)
plt.axis('square')
plt.axis([-6,6,-6,6])
plt.legend([a1,a2,a3],['v','w','v+w'])
plt.title('Vectors v, w and v + w')
# plt.savefig('Figure_02_02a.png',dpi=300) # write out the fig to a file
plt.show()

# %% [markdown]
# ## Vector Subtraction

# %%
x = v - w

# plot that vector (and a dot for the tail)
# plt.arrow(x, y, dx, dy, **kwargs)
# This draws an arrow from (x, y) to (x+dx, y+dy).
plt.arrow(0,0,v[0],v[1],head_width=.5,width=.1, color=[.3,.3,.3], length_includes_head=True, label='v')
plt.arrow(0,0,w[0],w[1],head_width=.5,width=.1, color=[.5,.5,.5], length_includes_head=True, label='w')

plt.plot(0,0,'ko',markerfacecolor='k',markersize=7)

# plot result vector
plt.arrow(0,0,x[0],x[1],head_width=.5,width=.1, color=[.5,.9,.5], length_includes_head=True, label='v-w')

# plot a box around vector
plt.plot([v[0], x[0]], [v[1], x[1]],'--', color=[.8,.8,.8], zorder=-1, linewidth=2)
plt.plot([x[0], w[0]], [x[1], w[1]],'--', color=[.8,.8,.8], zorder=-1, linewidth=2)

# plot geometric meaning
plt.plot([w[0], v[0]], [w[1], v[1]],'--', color=[.8,.8,.8], zorder=-1, linewidth=2)

# add axis lines
plt.plot([-8,8],[0,0],'--',color=[.8,.8,.8],zorder=-1)
plt.plot([0,0],[-8,8],'--',color=[.8,.8,.8],zorder=-1)

# make the plot look nicer
plt.axis('square')
plt.axis([-8,8,-8,8])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Vector Subtraction')
plt.grid(color = 'blue', linestyle = '--', linewidth = 0.5)
plt.xticks(np.arange(-8, 9, 2))
plt.legend()
plt.show()

# %% [markdown]
# >The difference vector is the line that goes from the head of the “negative” vector to the head of the “positive” vector.

# %%
# vector difference
vMinusW = v-w

# now plot all three vectors
plt.figure(figsize=(6,6))

a1 = plt.arrow(0,0,v[0],v[1],head_width=.3,width=.1,color='k',length_includes_head=True)
a2 = plt.arrow(0,0,w[0],w[1],head_width=.3,width=.1,color=[.5,.5,.5],length_includes_head=True)
a3 = plt.arrow(w[0],w[1],vMinusW[0],vMinusW[1],head_width=.3,width=.1,color=[.8,.8,.8],length_includes_head=True)


# make the plot look a bit nicer
plt.grid(linestyle='--',linewidth=.5)
plt.axis('square')
plt.axis([-6,6,-6,6])
plt.legend([a1,a2,a3],['v','w','v-w'])
plt.title('Vectors v, w and v - w')
# plt.savefig('Figure_02_02b.png',dpi=300)
plt.show()

# %% [markdown]
# ## Distance between vectors

# %%
np.linalg.norm(v-w)
# Out:
# 8.54400374531753

# %%
from scipy.spatial import distance

distance.euclidean(v, w)
# Out:
# 8.54400374531753

# %% [markdown]
# # Dot Product
#
# It is element-wise multiplication and sum of vector elements.
#
#
# The function np.dot() does not actually implement the vector dot product; it implements matrix multiplication, which is a collection of dot products. This will make more sense after learning about the rules and mechanisms of matrix multiplication.

# %%
v = np.array([1,2,3,4])
w = np.array([5,6,7,8])
np.dot(v,w)
# Out:
# 70

# %% [markdown]
# # Geometric meaning
#
# Dot product is the length of projection of A on B multiplied by ||B||
#
# ![Alt text](image-1.png)
#
# We can calculate the Dot Product of two vectors this way:
# a · b = |a| × |b| × cos(θ)
#
# Where:
# |a| is the magnitude (length) of vector a
# |b| is the magnitude (length) of vector b
# θ is the angle between a and b
#
# * Dot product is the measure of how similar the vectors are.
# * The Dot product is the product of the magnitudes of the two vectors, scaled by the cosine of the angle between them.
# * when the dot product is zero, then the two vectors are orthogonal(θ = 90 degree)

# %% [markdown]
# # Orthogonal Vector Decomposition
#
# To “decompose” a vector or matrix means to break up that matrix into multiple simpler pieces. Decompositions are used to reveal information that is “hidden” in a matrix, to make the matrix easier to work with, or for data compression. It is no understatement to write that much of linear algebra (in the abstract and in practice) involves matrix decompositions. Matrix decompositions are a big deal.
#
#
# Let me introduce the concept of a decomposition using two simple examples with scalars:
# * We can decompose the number 42.01 into two pieces: 42 and .01. Perhaps .01 is noise to be ignored, or perhaps the goal is to compress the data (the integer 42 requires less memory than the floating-point 42.01). Regardless of the motivation, the decomposition involves representing one mathematical object as the sum of simpler objects (42 = 42 + .01).
#
# * We can decompose the number 42 into the product of prime numbers 2, 3, and 7. This decomposition is called prime factorization and has many applications in numerical processing and cryptography. This example involves products instead of sums, but the point is the same: decompose one mathematical object into smaller, simpler pieces.

# %% [markdown]
# # Intuition for Matrices
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
