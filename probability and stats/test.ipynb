# %%
import numpy as np
import pandas as pd
from scipy import stats
from matplotlib import pyplot as plt
import seaborn as sns

# %%
l = [x**2 for x in range(36)]
l[1:10:3]
# Out:
# [1, 16, 49]

# %%
def calculate_column_mean(d, k):
    s = 0
    l = len(d)
    for i in range(l):
        s += d[i][k]
    return s/l


data = [{
    "score":84
},
{
    "score":50
}
]
calculate_column_mean(data, 'score')
# Out:
# 67.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# degrees of freedom
df = 10

# range of x values
x = np.linspace(-4, 4, 1000)

# calculate the t-distribution pdf for the given df and x values
pdf = t.pdf(x, df)

# plot the t-distribution pdf
plt.plot(x, pdf)
plt.title('t-Distribution (df={})'.format(df))
plt.xlabel('x')
plt.ylabel('pdf')
plt.show()

# %% [markdown]
# ## Chi2 contigency test

# %%
index=['High school', 'Bachelors', 'Masters', 'Phd', 'Total']
female_o = [60, 54, 46, 41, 201]
male_o = [40, 44, 53, 57, 194]
total_o = [100, 98, 99, 98, 395]

female_e = [50.866, 49.868, 50.377, 49.868, 201]
male_e = [49.114, 48.132, 48.623, 48.132, 194]
total_e = [100, 98, 99, 98, 395]

observed = pd.DataFrame({'Female':female_o, 'male':male_o, 'total':total_o},
    index=index)

observed
# Out:
#              Female  male  total
# High school      60    40    100
# Bachelors        54    44     98
# Masters          46    53     99
# Phd              41    57     98
# Total           201   194    395

# %%
expected = pd.DataFrame({'Female':female_e, 'male':male_e, 'total':total_e},
    index=index)

expected
# Out:
#               Female     male  total
# High school   50.866   49.114    100
# Bachelors     49.868   48.132     98
# Masters       50.377   48.623     99
# Phd           49.868   48.132     98
# Total        201.000  194.000    395

# %%
observed.loc[:,['Female', 'male']].values[:-1]
# Out:
# array([[60, 40],
#        [54, 44],
#        [46, 53],
#        [41, 57]], dtype=int64)

# %%
chi_stat, p_value, df, exp_freq = stats.chi2_contingency(observed.loc[:,['Female', 'male']].values[:-1])

# %%
print(chi_stat, p_value)
# Out:
# 8.006066246262538 0.04588650089174722

# %%
np.array([[10, 10, 20], [20, 20, 20]]).ravel()
# Out:
# array([10, 10, 20, 20, 20, 20])

# %%
import numpy as np
from scipy import stats
from scipy.stats import chi2_contingency
from scipy.stats import chi2
from scipy.stats import chisquare

# %%
observed = np.array([73, 38, 18])
expected = sum(observed) * np.array([.6, .28, .12])

# %%
chisquare(observed, expected)
# Out:
# Power_divergenceResult(statistic=0.7582133628645247, pvalue=0.6844725882551137)

# %%
mean_sat = 1060
sigma1 = 210
sat = np.random.normal(mean_sat, sigma1, size=1000)
sns.displot(sat, kde=True, alpha=0.5)

# %%
x = np.linspace(stats.norm.ppf(0.01),
                stats.norm.ppf(0.99), 100)
x
# Out:
# array([-2.32634787, -2.27935095, -2.23235402, -2.18535709, -2.13836017,
#        -2.09136324, -2.04436631, -1.99736939, -1.95037246, -1.90337553,
#        -1.85637861, -1.80938168, -1.76238475, -1.71538783, -1.6683909 ,
#        -1.62139397, -1.57439705, -1.52740012, -1.48040319, -1.43340627,
#        -1.38640934, -1.33941241, -1.29241549, -1.24541856, -1.19842163,
#        -1.15142471, -1.10442778, -1.05743085, -1.01043393, -0.963437  ,
#        -0.91644007, -0.86944314, -0.82244622, -0.77544929, -0.72845236,
#        -0.68145544, -0.63445851, -0.58746158, -0.54046466, -0.49346773,
#        -0.4464708 , -0.39947388, -0.35247695, -0.30548002, -0.2584831 ,
#        -0.21148617, -0.16448924, -0.11749232, -0.07049539, -0.02349846,
#         0.02349846,  0.07049539,  0.11749232,  0.16448924,  0.21148617,
#         0.2584831 ,  0.30548002,  0.35247695,  0.39947388,  0.4464708 ,
#         0.49346773,  0.54046466,  0.58746158,  0.63445851,  0.68145544,
# ...

# %%
# x = sat
rv = stats.norm()
plt.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')
plt.legend()
plt.show()

# %%
import math 
def pdf(x, mu, sigma):
    coefficient = 1 / (sigma * math.sqrt(2 * math.pi))
    exponent = -(x - mu) ** 2 / (2 * sigma ** 2)
    return coefficient * math.exp(exponent)

pdf_val = []
for i in range(2000):
    pdf_val.append(pdf(i, sat.mean(), sat.std()))
plt.plot(pdf_val)

# %%
chi2.isf(.05, 2)
# Out:
# 5.991464547107983

# %%
chisquare([16, 18, 16, 14, 12, 12])
# Out:
# Power_divergenceResult(statistic=2.0, pvalue=0.8491450360846096)

# %%
import numpy as np
import statsmodels.api as statmod
import matplotlib.pyplot as plt

import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

#create dataset with 100 values that follow a normal distribution
data = np.random.normal(0,1,100)
#create Q-Q plot with 45-degree line added to plot
fig = statmod.qqplot(data, line='45')
plt.show()

# %% [markdown]
# #### Parametric statistics are based on assumptions about the distribution of population from which the sample was taken. <br>
# #### Nonparametric statistics are not based on assumptions, that is, the data can be collected from a sample that does not follow a specific distribution.
#
# Common parametric statistics are, for example, the Student's t-tests. Common nonparametric statistics are, for example, the Mann-Whitney-Wilcoxon (MWW) test or the Wilcoxon test.
#
# - Background of parametric and nonparametric statistics<br>
# In parametric statistics, the information about the distribution of the population is known and is based on a fixed set of parameters. In nonparametric statistics, the information about the distribution of a population is unknown, and the parameters are not fixed, which makes is necessary to test the hypothesis for the population.
#
#
# - Usage of parametric and nonparametric statistics<br>
# To decide whether to use parametric or nonparametric statistics, you should consider several criteria about the sample data and the assumptions, and carefully evaluate the validity of those assumptions.
#
#
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('NHS_india.csv')
df

# %%
data = np.random.normal(0,1,100)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = np.random.normal(0,1,100)
#       2 data
#
# NameError: name 'np' is not defined

# %%
## PMF
weight = np.random.binomial(100, 0.8, size=200)
plt.hist(weight)
# Out:
# (array([ 1.,  1.,  4., 25., 26., 32., 58., 28., 18.,  7.]),
#  array([66. , 68.3, 70.6, 72.9, 75.2, 77.5, 79.8, 82.1, 84.4, 86.7, 89. ]),
#  <BarContainer object of 10 artists>)

# %%
# - Calculating PMF for weight
a, b = np.unique(weight, return_counts=True)
pmf = b/np.sum(b)
pmf
# Out:
# array([0.005, 0.005, 0.005, 0.015, 0.035, 0.03 , 0.06 , 0.06 , 0.07 ,
#        0.075, 0.085, 0.09 , 0.085, 0.115, 0.095, 0.045, 0.025, 0.065,
#        0.02 , 0.01 , 0.005])

# %%
# values along with probability mass function
# display(np.column_stack((a, pmf)))
plt.bar(a, pmf)
sns.kdeplot(weight, color='r')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.histplot(weight, stat='probability', bins=20)
# Out:
# <Axes: ylabel='Probability'>

# %%
pdf = stats.norm.pdf(np.unique(weight), loc=weight.mean(), scale=weight.std())
plt.plot(pdf)

# %%
## CDF

# - Calcualting cdf for weight
cdf = np.cumsum(pmf)
plt.plot(a, cdf)
fig, ax = plt.subplots(figsize=(8, 4))
ax.hist(weight, density = 1, histtype='barstacked',cumulative=True, label='CDF')
plt.legend()
plt.show()

# %%
sample2 = [10,15,20,20,25,33,40,51,51,60,64,64,64]
df3 = pd.DataFrame(sample2,columns=['Sample'])
probabilities = df3['Sample'].value_counts(normalize=True)    

plt.bar(probabilities.index, probabilities.values, color='blue')
sns.displot(df3, legend='', kind='kde')
